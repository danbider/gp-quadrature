# %% [markdown]
# # ERA5 2m Temperature — Global Monthly Mean

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.optim import Adam
import sys
sys.path.append('..')
from efgpnd import EFGPND
from load_era5 import load_era5_torch

# %%
# Load data
x, y = load_era5_torch(n_sub=1_000_000)
# x, y = load_era5_torch()
print(f"x shape: {x.shape}")   # (N, 2) — lon, lat
print(f"y shape: {y.shape}")   # (N,) — temperature (°C)
print(f"Lon range: {x[:,0].min():.2f} to {x[:,0].max():.2f}")
print(f"Lat range: {x[:,1].min():.2f} to {x[:,1].max():.2f}")
print(f"Temp range: {y.min():.1f} to {y.max():.1f} °C")
# Out:
# x shape: torch.Size([1000000, 2])
# y shape: torch.Size([1000000])
# Lon range: -179.75 to 180.00
# Lat range: -90.00 to 90.00
# Temp range: -47.9 to 34.4 °C

# %%
# # Plot raw data
# fig, ax = plt.subplots(figsize=(14, 6))
# sc = ax.scatter(x[:,0].numpy(), x[:,1].numpy(), c=y.numpy(), s=0.3,
#                 cmap='RdYlBu_r', alpha=0.7, rasterized=True)
# ax.set_xlabel('Longitude')
# ax.set_ylabel('Latitude')
# ax.set_title('ERA5 2m Temperature (°C) — 50k subsample')
# plt.colorbar(sc, ax=ax, label='Temperature (°C)')
# ax.set_aspect(1.5)
# plt.tight_layout()

# %%
# Normalize inputs to [0, 1] and standardize outputs
x_min, x_max = x.min(dim=0).values, x.max(dim=0).values
x = (x - x_min) / (x_max - x_min)

y_mean, y_std = y.mean(), y.std()
y = (y - y_mean) / y_std

print(f"x range per dim: {x.min(dim=0).values.tolist()} to {x.max(dim=0).values.tolist()}")
print(f"y mean={y.mean():.4f}, std={y.std():.4f}")
# Out:
# x range per dim: [0.0, 0.0] to [1.0, 1.0]
# y mean=-0.0000, std=1.0000

# %%
EPSILON = 1e-4
kernel_type = 'SquaredExponential'
cg_tol = 1e-5

# %%
max_iters = 50
J = 1

training_log = {
    'iter': [],
    'lengthscale': [],
    'variance': [],
    'sigmasq': [],
}

model = EFGPND(x, y, kernel=kernel_type, eps=EPSILON)
optimizer = Adam(model.parameters(), lr=0.2)

for it in range(max_iters):
    optimizer.zero_grad()
    model.compute_gradients(trace_samples=J, cg_tol=cg_tol)
    optimizer.step()

    lengthscale = model.kernel.get_hyper('lengthscale')
    variance = model.kernel.get_hyper('variance')
    sigmasq = model._gp_params.sig2.item()
    training_log['iter'].append(it)
    training_log['lengthscale'].append(lengthscale)
    training_log['variance'].append(variance)
    training_log['sigmasq'].append(sigmasq)

    if it % 10 == 0:
        print(f"iter {it:>3}  ℓ={lengthscale:.4g}  σ_f²={variance:.4g}  σ_n²={sigmasq:.4g}")

print(f"Final: ℓ={lengthscale:.4g}, σ_f²={variance:.4g}, σ_n²={sigmasq:.4g}")
# Out:
# iter   0  ℓ=0.2158  σ_f²=1.131  σ_n²=0.1666
# iter  10  ℓ=0.03249  σ_f²=2.703  σ_n²=0.02409
# iter  20  ℓ=0.006723  σ_f²=3.566  σ_n²=0.003207
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 16
#      14 for it in range(max_iters):
#      15     optimizer.zero_grad()
# ---> 16     model.compute_gradients(trace_samples=J, cg_tol=cg_tol)
#      17     optimizer.step()
#      19     lengthscale = model.kernel.get_hyper('lengthscale')
#
# File ~/Documents/GPs/gp-quadrature/efgpnd.py:680, in EFGPND.compute_gradients(self, trace_samples, do_profiling, nufft_eps, cg_tol, noise_floor, apply_gradients, compute_log_marginal, log_marginal_probes, log_marginal_steps, verbose, frozen_grid, max_mtot_1d, **kwargs)
#     678 gradient_stats = {}
#     679 # Compute gradients with respect to the original parameters
# --> 680 result = efgpnd_gradient_batched(
#     681     self.x, self.y,
#     682     sigmasq=self._gp_params.sig2,
#     683     kernel=self.kernel,
#     684     eps=self.eps,
#     685     trace_samples=trace_samples,
#     686     x0=x0, x1=x1,
#     687     do_profiling=do_profiling,
#     688     nufft_eps=nufft_eps,
#     689     cg_tol=cg_tol,
#     690     noise_floor=noise_floor,
#     691     stats_out=gradient_stats,
#     692     mean_cg_init=self._last_gradient_beta if use_mean_cg_warm_start else None,
#     693     use_mean_cg_preconditioner=use_mean_cg_preconditioner,
#     694     use_trace_cg_preconditioner=use_trace_cg_preconditioner,
#     695     frozen_grid=frozen_grid,
#     696     max_mtot_1d=max_mtot_1d,
#     697     **log_marginal_kwargs,
#     698     **kwargs
#     699 )
#     700 self._last_gradient_beta = gradient_stats.pop("mean_beta", None)
#     701 self.last_gradient_stats = gradient_stats
#
# File ~/Documents/GPs/gp-quadrature/efgpnd.py:239, in efgpnd_gradient_batched(x, y, sigmasq, kernel, eps, trace_samples, x0, x1, nufft_eps, cg_tol, early_stopping, device, do_profiling, compute_log_marginal, noise_floor, stats_out, mean_cg_init, use_mean_cg_preconditioner, use_trace_cg_preconditioner, frozen_grid, max_mtot_1d, log_marginal_probes, log_marginal_steps)
#     233 t1 = time.time()
#     234 cg_trace = ConjugateGradients(
#     235     A_apply_batch, B_all, torch.zeros_like(B_all),
#     236     tol=cg_tol, early_stopping=early_stopping,
#     237     M_inv_apply=trace_M_inv
#     238 )
# --> 239 Beta_all = cg_trace.solve()
#     240 t2 = time.time()
#     241 # print(f"CG Time taken: {t2 - t1} seconds")
#     242 # print(cg.iters_completed)
#
# File ~/Documents/GPs/gp-quadrature/cg.py:82, in ConjugateGradients.solve(self)
#      74 """
#      75 Solve the linear system(s) using Conjugate Gradients.
#      76 Automatically handles single or batched systems.
#    (...)
#      79     x (torch.Tensor): Solution to the system(s)
#      80 """
#      81 if self.is_batched:
# ---> 82     return self._solve_batched()
#      83 else:
#      84     return self._solve_single()
#
# File ~/Documents/GPs/gp-quadrature/cg.py:202, in ConjugateGradients._solve_batched(self)
#     199     break
#     201 # Compute matrix-vector product for active systems
# --> 202 Ap = self.A_apply_function(p[idx])  # (k, n)
#     204 # Compute step sizes
#     205 pAp = torch.sum(p[idx].conj() * Ap, dim=1).real + self.div_eps  # (k,)
#
# File ~/Documents/GPs/gp-quadrature/efgpnd.py:1658, in create_A_mean.<locals>.A_mean(beta)
#    1657 def A_mean(beta):
# -> 1658     return Gv(beta) + sigmasq_scalar * beta
#
# File ~/Documents/GPs/gp-quadrature/efgpnd.py:1647, in create_Gv.<locals>.Gv(v)
#    1645 shape_in = (v.shape[0], *ns_shape)
#    1646 v_block = v.view(shape_in)
# -> 1647 Tv = toeplitz(ws_block * v_block)
#    1648 result = ws_block * Tv
#    1649 return result.view(v.shape)
#
# File ~/Documents/GPs/gp-quadrature/efgpnd.py:1439, in ToeplitzND.__call__(self, x)
#    1436     y_fft = x_fft * fftn(self.v_pad, dim=self.fft_dims)
#    1438 # Inverse FFT
# -> 1439 y = ifftn(y_fft, dim=list(range(-self.d, 0)))
#    1441 # --- Extract central block ---
#    1442 # Create slices for the batch dimensions
#    1443 slices = [slice(None)] * (y.ndim - self.d)
#
# KeyboardInterrupt:

# %%
# Plot optimization path
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(training_log['lengthscale'], training_log['variance'], 'o-')
ax1.scatter(training_log['lengthscale'][0], training_log['variance'][0], color='green', s=80, label='Start', zorder=5)
ax1.scatter(training_log['lengthscale'][-1], training_log['variance'][-1], color='red', s=80, label='End', zorder=5)
ax1.set_xlabel('Lengthscale (ℓ)')
ax1.set_ylabel('Variance (σ_f²)')
ax1.set_title('Optimization path')
ax1.legend()
ax1.grid(True)

ax2.plot(training_log['iter'], training_log['lengthscale'], label='ℓ')
ax2.plot(training_log['iter'], training_log['variance'], label='σ_f²')
ax2.plot(training_log['iter'], training_log['sigmasq'], label='σ_n²')
ax2.set_xlabel('Iteration')
ax2.set_ylabel('Value')
ax2.set_title('Hyperparameters vs iteration')
ax2.legend()
ax2.grid(True)

plt.tight_layout()

# %%
# Predict posterior mean on a grid
grid_res = 200
g0 = torch.linspace(0, 1, grid_res, dtype=x.dtype)
g1 = torch.linspace(0, 1, grid_res, dtype=x.dtype)
G0, G1 = torch.meshgrid(g0, g1, indexing='ij')
x_new = torch.stack([G0.flatten(), G1.flatten()], dim=1)

mean_pred = model.predict(x_new=x_new, return_variance=False)
mean_pred = mean_pred[0] if isinstance(mean_pred, tuple) else mean_pred

# Inverse transform back to original scales
mean_grid = (mean_pred.detach().cpu() * y_std + y_mean).numpy().reshape(grid_res, grid_res)
lon_grid = (G0.numpy() * (x_max[0] - x_min[0]).item() + x_min[0].item())
lat_grid = (G1.numpy() * (x_max[1] - x_min[1]).item() + x_min[1].item())

# %%
# Plot posterior mean
fig, ax = plt.subplots(figsize=(14, 6))
pcm = ax.pcolormesh(lon_grid, lat_grid, mean_grid, cmap='RdYlBu_r',
                     shading='auto', rasterized=True)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('EFGP Posterior Mean — Temperature (°C)')
plt.colorbar(pcm, ax=ax, label='Temperature (°C)')
ax.set_aspect(1.5)
plt.tight_layout()
