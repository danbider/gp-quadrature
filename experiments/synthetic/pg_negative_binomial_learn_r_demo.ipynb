# %% [markdown]
# # Polyagamma GP Negative Binomial Demo With Learned `r`
#
# This notebook mirrors `pg_negative_binomial_demo.ipynb`, but also learns the negative-binomial shape parameter `r` (`total_count` in the code) during the M-step.
#
# The setup stays close to the toy-data pattern in `PG_GP4.ipynb`:
#
# - random points in `[-1, 1]^2`,
# - a latent GP sample `f`,
# - counts drawn from a negative binomial likelihood with true shape `r_true` and logits `f`,
# - fitting from a mismatched initial `r_init` so the learned `r` trajectory is visible.

# %%
import os
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.distributions import NegativeBinomial

os.environ.setdefault("KMP_DUPLICATE_LIB_OK", "TRUE")

from vanilla_gp_sampling import sample_gp_spectral_approx, squared_exponential_kernel
from polyagamma_classification.pg_classifier import PolyagammaGPNegativeBinomialRegressor

torch.set_default_dtype(torch.float64)
torch.manual_seed(1)
np.random.seed(1)

plt.style.use("seaborn-v0_8-whitegrid")

# %% [markdown]
# ## Generate The Same Style Of Toy Data As `PG_GP4.ipynb`
#
# We keep the same 2D random-input construction. The observation model is negative binomial with logits given by the latent GP, but for this larger synthetic example we draw the latent field with the same spectral/NUFFT kernel approximation used by the PG model itself. We also deliberately initialize the estimator with the wrong `r` so the learning dynamics are visible.

# %%
n_train = 50_000
d = 2
true_length_scale = 0.1
true_variance = 1.0
true_total_count = 1.0
init_total_count = 2.25
grid_size = 24

X_train = torch.rand(n_train, d) * 2.0 - 1.0
grid_1d = torch.linspace(-1.1, 1.1, grid_size)
gx, gy = torch.meshgrid(grid_1d, grid_1d, indexing="ij")
X_grid = torch.stack([gx.reshape(-1), gy.reshape(-1)], dim=1)

X_all = torch.cat([X_train, X_grid], dim=0)
f_all = sample_gp_spectral_approx(
    X_all,
    num_samples=1,
    length_scale=true_length_scale,
    variance=true_variance,
    spectral_eps=1e-4,
    trunc_eps=1e-4,
    nufft_eps=1e-7,
    seed=12,
)
y_all = NegativeBinomial(
    total_count=torch.tensor(true_total_count, dtype=torch.float64),
    logits=f_all,
).sample()

y_train = y_all[:n_train]
f_train_true = f_all[:n_train]
f_grid_true = f_all[n_train:]
mean_count_grid_true = true_total_count * torch.exp(f_grid_true)

X_train_np = X_train.cpu().numpy()
y_train_np = y_train.cpu().numpy().astype(np.float64)
X_grid_np = X_grid.cpu().numpy()
grid_1d_np = grid_1d.cpu().numpy()

print(f"Training points: {n_train}")
print(f"Grid points: {X_grid_np.shape[0]}")
print(f"True total_count r: {true_total_count:.2f}")
print(f"Initial total_count r: {init_total_count:.2f}")
print(f"Mean observed count: {y_train_np.mean():.3f}")
# Out:
# Training points: 50000
# Grid points: 576
# True total_count r: 1.00
# Initial total_count r: 2.25
# Mean observed count: 1.753

# %% [markdown]
# ## Fit `PolyagammaGPNegativeBinomialRegressor` With Learned `r`
#
# The kernel hyperparameters still use the same PG spectral M-step as before. The extra scalar update here learns `log(r)` from the E-step marginals `q(f_i) = N(\mu_i, \sigma_i^2)` via a cheap Gauss-Hermite approximation to $\mathbb{E}[\log \sigma(-f_i)]$.

# %%
reg = PolyagammaGPNegativeBinomialRegressor(
    total_count=init_total_count,
    learn_total_count=False,
    total_count_lr=0.05,
    total_count_update_frequency=1,
    total_count_quadrature_nodes=16,
    lengthscale_init=0.30,
    variance_init=1.0,
    max_iter=100,
    e_step_iters=1,
    final_e_step_iters=2,
    rho0=0.7,
    gamma=1e-3,
    lr=0.1,
    n_e_probes=1,
    n_m_probes=1,
    cg_tol=1e-5,
    nufft_eps=1e-6,
    spectral_eps=1e-4,
    trunc_eps=1e-4,
    prediction_batch_size=256,
    predictive_variance_method="chebyshev",
    predictive_variance_chebyshev_nodes=7,
    use_exact_weighted_toeplitz_operator=True,
    random_state=0,
    device='cpu',
    store_history=True,
    verbose=1,
)

t0 = time.time()
reg.fit(X_train_np, y_train_np)
fit_time = time.time() - t0

print(f"Fit time: {fit_time:.2f} s")
print(f"Learned lengthscale: {reg.lengthscale_:.4f}")
print(f"Learned variance: {reg.variance_:.4f}")
print(f"Learned total_count r: {reg.total_count_:.4f}")
print(f"Training mean absolute error: {reg.training_mean_absolute_error_:.3f}")
# Out:
# outer   0 lengthscale=0.27503 variance=1.06436 grad=(-2.882e+04, +7.378e+02) count_mae=1.7141
# outer   1 lengthscale=0.25186 variance=1.13096 grad=(-3.213e+04, +7.016e+02) count_mae=1.6901
# outer   2 lengthscale=0.23049 variance=1.19948 grad=(-3.215e+04, +6.265e+02) count_mae=1.6700
# outer   3 lengthscale=0.21096 variance=1.26899 grad=(-2.923e+04, +4.903e+02) count_mae=1.6527
# outer   4 lengthscale=0.19326 variance=1.33867 grad=(-2.633e+04, +3.836e+02) count_mae=1.6394
# outer   5 lengthscale=0.17730 variance=1.40807 grad=(-2.420e+04, +3.152e+02) count_mae=1.6286
# outer   6 lengthscale=0.16284 variance=1.47684 grad=(-2.489e+04, +2.657e+02) count_mae=1.6190
# outer   7 lengthscale=0.14978 variance=1.54482 grad=(-2.349e+04, +2.320e+02) count_mae=1.6106
# outer   8 lengthscale=0.13809 variance=1.61129 grad=(-2.058e+04, +1.802e+02) count_mae=1.6029
# outer   9 lengthscale=0.12777 variance=1.67495 grad=(-1.484e+04, +1.132e+02) count_mae=1.5987
# outer  10 lengthscale=0.11878 variance=1.73493 grad=(-1.013e+04, +6.688e+01) count_mae=1.5952
# outer  11 lengthscale=0.11101 variance=1.79067 grad=(-6.044e+03, +3.471e+01) count_mae=1.5947
# outer  12 lengthscale=0.10434 variance=1.84154 grad=(-2.907e+03, +2.068e+00) count_mae=1.5944
# outer  13 lengthscale=0.09866 variance=1.88696 grad=(+9.653e+02, -2.697e+01) count_mae=1.5931
# outer  14 lengthscale=0.09389 variance=1.92655 grad=(+4.719e+03, -4.953e+01) count_mae=1.5928
# outer  15 lengthscale=0.08987 variance=1.96081 grad=(+4.936e+03, -4.930e+01) count_mae=1.5926
# outer  16 lengthscale=0.08655 variance=1.98919 grad=(+8.471e+03, -7.491e+01) count_mae=1.5915
# outer  17 lengthscale=0.08381 variance=2.01246 grad=(+8.803e+03, -6.794e+01) count_mae=1.5906
# outer  18 lengthscale=0.08157 variance=2.03066 grad=(+9.508e+03, -7.686e+01) count_mae=1.5904
# outer  19 lengthscale=0.07980 variance=2.04388 grad=(+1.197e+04, -8.546e+01) count_mae=1.5903
# outer  20 lengthscale=0.07846 variance=2.05214 grad=(+1.322e+04, -9.510e+01) count_mae=1.5901
# outer  21 lengthscale=0.07746 variance=2.05603 grad=(+1.212e+04, -9.087e+01) count_mae=1.5902
# outer  22 lengthscale=0.07683 variance=2.05492 grad=(+1.559e+04, -1.157e+02) count_mae=1.5888
# outer  23 lengthscale=0.07650 variance=2.04971 grad=(+1.397e+04, -1.041e+02) count_mae=1.5895
# outer  24 lengthscale=0.07644 variance=2.04063 grad=(+1.386e+04, -1.075e+02) count_mae=1.5908
# outer  25 lengthscale=0.07660 variance=2.02789 grad=(+1.294e+04, -1.108e+02) count_mae=1.5884
# outer  26 lengthscale=0.07698 variance=2.01192 grad=(+1.337e+04, -1.084e+02) count_mae=1.5904
# outer  27 lengthscale=0.07754 variance=1.99369 grad=(+1.174e+04, -9.147e+01) count_mae=1.5891
# outer  28 lengthscale=0.07828 variance=1.97312 grad=(+1.216e+04, -9.888e+01) count_mae=1.5892
# outer  29 lengthscale=0.07918 variance=1.95041 grad=(+1.210e+04, -9.951e+01) count_mae=1.5900
# outer  30 lengthscale=0.08027 variance=1.92583 grad=(+1.270e+04, -9.745e+01) count_mae=1.5894
# outer  31 lengthscale=0.08149 variance=1.89928 grad=(+1.105e+04, -1.051e+02) count_mae=1.5903
# outer  32 lengthscale=0.08287 variance=1.87097 grad=(+1.192e+04, -1.050e+02) count_mae=1.5896
# outer  33 lengthscale=0.08436 variance=1.84189 grad=(+9.573e+03, -8.441e+01) count_mae=1.5907
# outer  34 lengthscale=0.08598 variance=1.81214 grad=(+1.048e+04, -8.466e+01) count_mae=1.5911
# outer  35 lengthscale=0.08771 variance=1.78184 grad=(+9.372e+03, -8.321e+01) count_mae=1.5905
# outer  36 lengthscale=0.08948 variance=1.75209 grad=(+6.674e+03, -5.720e+01) count_mae=1.5914
# outer  37 lengthscale=0.09134 variance=1.72265 grad=(+8.101e+03, -6.281e+01) count_mae=1.5916
# outer  38 lengthscale=0.09328 variance=1.69318 grad=(+7.438e+03, -7.040e+01) count_mae=1.5910
# outer  39 lengthscale=0.09523 variance=1.66446 grad=(+5.418e+03, -5.141e+01) count_mae=1.5922
# outer  40 lengthscale=0.09719 variance=1.63640 grad=(+4.399e+03, -5.195e+01) count_mae=1.5913
# outer  41 lengthscale=0.09909 variance=1.60976 grad=(+2.990e+03, -3.199e+01) count_mae=1.5921
# outer  42 lengthscale=0.10100 variance=1.58428 grad=(+3.932e+03, -3.474e+01) count_mae=1.5923
# outer  43 lengthscale=0.10286 variance=1.56007 grad=(+2.745e+03, -2.949e+01) count_mae=1.5924
# outer  44 lengthscale=0.10458 variance=1.53775 grad=(+1.009e+02, -1.090e+01) count_mae=1.5926
# outer  45 lengthscale=0.10613 variance=1.51738 grad=(-9.373e+02, -4.555e+00) count_mae=1.5931
# outer  46 lengthscale=0.10757 variance=1.49856 grad=(+1.822e+02, -1.022e+01) count_mae=1.5933
# outer  47 lengthscale=0.10875 variance=1.48256 grad=(-3.408e+03, +2.560e+01) count_mae=1.5932
# outer  48 lengthscale=0.10972 variance=1.46853 grad=(-2.627e+03, +1.108e+01) count_mae=1.5928
# outer  49 lengthscale=0.11046 variance=1.45654 grad=(-3.255e+03, +1.771e+01) count_mae=1.5929
# outer  50 lengthscale=0.11099 variance=1.44687 grad=(-3.318e+03, +2.950e+01) count_mae=1.5930
# outer  51 lengthscale=0.11128 variance=1.43935 grad=(-4.193e+03, +3.054e+01) count_mae=1.5935
# outer  52 lengthscale=0.11134 variance=1.43410 grad=(-4.262e+03, +3.854e+01) count_mae=1.5929
# outer  53 lengthscale=0.11119 variance=1.43077 grad=(-4.595e+03, +3.504e+01) count_mae=1.5927
# outer  54 lengthscale=0.11084 variance=1.42981 grad=(-4.360e+03, +5.008e+01) count_mae=1.5930
# outer  55 lengthscale=0.11039 variance=1.42932 grad=(-2.754e+03, +9.250e+00) count_mae=1.5934
# outer  56 lengthscale=0.10983 variance=1.42965 grad=(-3.217e+03, +1.854e+01) count_mae=1.5931
# outer  57 lengthscale=0.10920 variance=1.43049 grad=(-2.670e+03, +1.279e+01) count_mae=1.5935
# outer  58 lengthscale=0.10849 variance=1.43268 grad=(-2.930e+03, +3.329e+01) count_mae=1.5935
# outer  59 lengthscale=0.10777 variance=1.43499 grad=(-1.910e+03, +7.647e+00) count_mae=1.5932
# outer  60 lengthscale=0.10701 variance=1.43686 grad=(-2.091e+03, -5.185e+00) count_mae=1.5925
# outer  61 lengthscale=0.10621 variance=1.43907 grad=(-2.573e+03, +1.144e+01) count_mae=1.5937
# outer  62 lengthscale=0.10539 variance=1.44143 grad=(-2.248e+03, +8.221e+00) count_mae=1.5924
# outer  63 lengthscale=0.10465 variance=1.44360 grad=(-2.523e+01, +4.116e-01) count_mae=1.5933
# outer  64 lengthscale=0.10390 variance=1.44538 grad=(-1.632e+03, -4.164e+00) count_mae=1.5927
# outer  65 lengthscale=0.10321 variance=1.44687 grad=(-4.809e+02, -2.724e+00) count_mae=1.5933
# outer  66 lengthscale=0.10265 variance=1.44776 grad=(+1.331e+03, -9.873e+00) count_mae=1.5930
# outer  67 lengthscale=0.10210 variance=1.44852 grad=(-7.849e+02, -1.302e+00) count_mae=1.5932
# outer  68 lengthscale=0.10171 variance=1.44828 grad=(+2.291e+03, -1.984e+01) count_mae=1.5932
# outer  69 lengthscale=0.10129 variance=1.44734 grad=(-1.511e+03, -1.520e+01) count_mae=1.5924
# outer  70 lengthscale=0.10093 variance=1.44531 grad=(+3.974e+02, -2.510e+01) count_mae=1.5921
# outer  71 lengthscale=0.10061 variance=1.44237 grad=(+1.511e+02, -2.317e+01) count_mae=1.5922
# outer  72 lengthscale=0.10040 variance=1.43905 grad=(+1.718e+03, -1.384e+01) count_mae=1.5925
# outer  73 lengthscale=0.10023 variance=1.43464 grad=(+4.418e+02, -2.914e+01) count_mae=1.5926
# outer  74 lengthscale=0.10012 variance=1.43030 grad=(+9.449e+02, -7.426e+00) count_mae=1.5934
# outer  75 lengthscale=0.10008 variance=1.42479 grad=(+1.388e+03, -3.260e+01) count_mae=1.5929
# outer  76 lengthscale=0.10008 variance=1.41943 grad=(+7.184e+02, -7.774e+00) count_mae=1.5917
# outer  77 lengthscale=0.10009 variance=1.41437 grad=(+1.262e+02, -4.322e+00) count_mae=1.5917
# outer  78 lengthscale=0.10022 variance=1.40918 grad=(+2.790e+03, -1.272e+01) count_mae=1.5930
# outer  79 lengthscale=0.10037 variance=1.40417 grad=(+5.945e+02, -6.266e+00) count_mae=1.5914
# outer  80 lengthscale=0.10053 variance=1.39869 grad=(+4.205e+02, -1.950e+01) count_mae=1.5923
# outer  81 lengthscale=0.10073 variance=1.39341 grad=(+1.260e+03, -6.329e+00) count_mae=1.5924
# outer  82 lengthscale=0.10101 variance=1.38757 grad=(+1.862e+03, -2.195e+01) count_mae=1.5923
# outer  83 lengthscale=0.10130 variance=1.38167 grad=(+8.650e+02, -1.237e+01) count_mae=1.5929
# outer  84 lengthscale=0.10162 variance=1.37576 grad=(+1.169e+03, -1.150e+01) count_mae=1.5927
# outer  85 lengthscale=0.10192 variance=1.36922 grad=(+1.710e+02, -2.444e+01) count_mae=1.5931
# outer  86 lengthscale=0.10221 variance=1.36337 grad=(+3.502e+02, +1.427e+00) count_mae=1.5926
# outer  87 lengthscale=0.10250 variance=1.35689 grad=(+5.460e+02, -2.417e+01) count_mae=1.5930
# outer  88 lengthscale=0.10274 variance=1.35098 grad=(-6.797e+02, -9.743e-01) count_mae=1.5924
# outer  89 lengthscale=0.10288 variance=1.34601 grad=(-1.204e+03, +7.412e+00) count_mae=1.5928
# outer  90 lengthscale=0.10295 variance=1.34185 grad=(-1.233e+03, +6.519e+00) count_mae=1.5931
# outer  91 lengthscale=0.10298 variance=1.33758 grad=(-5.468e+02, -1.011e+01) count_mae=1.5929
# outer  92 lengthscale=0.10290 variance=1.33442 grad=(-1.986e+03, +1.386e+01) count_mae=1.5924
# outer  93 lengthscale=0.10283 variance=1.33072 grad=(+8.241e+01, -1.656e+01) count_mae=1.5923
# outer  94 lengthscale=0.10286 variance=1.32632 grad=(+1.567e+03, -2.097e+01) count_mae=1.5933
# outer  95 lengthscale=0.10286 variance=1.32288 grad=(-4.913e+02, +1.061e+01) count_mae=1.5926
# outer  96 lengthscale=0.10283 variance=1.31940 grad=(-4.030e+02, -7.346e+00) count_mae=1.5934
# outer  97 lengthscale=0.10275 variance=1.31582 grad=(-1.017e+03, -8.384e+00) count_mae=1.5927
# outer  98 lengthscale=0.10256 variance=1.31261 grad=(-2.066e+03, +3.153e-01) count_mae=1.5929
# outer  99 lengthscale=0.10240 variance=1.30906 grad=(+1.030e+01, -1.250e+01) count_mae=1.5927
# Fit time: 48.28 s
# Learned lengthscale: 0.1024
# Learned variance: 1.3091
# Learned total_count r: 2.2500
# Training mean absolute error: 1.593

# %%
# latent_train = reg.decision_function(X_train_np)
# var_train = reg.predictive_variance(X_train_np)
# mean_count_train = reg.total_count_ * np.exp(latent_train + 0.5 * var_train)

latent_grid = reg.decision_function(X_grid_np)
print('...')
var_grid = reg.predictive_variance(X_grid_np)
print('...')
mean_count_grid = reg.total_count_ * np.exp(latent_grid + 0.5 * var_grid)

f_grid_true_img = f_grid_true.cpu().numpy().reshape(grid_size, grid_size)
mean_count_grid_true_img = mean_count_grid_true.cpu().numpy().reshape(grid_size, grid_size)
latent_grid_img = latent_grid.reshape(grid_size, grid_size)
mean_count_grid_img = mean_count_grid.reshape(grid_size, grid_size)
var_grid_img = var_grid.reshape(grid_size, grid_size)

probe_points = np.array([
    [-0.75, -0.75],
    [0.00, 0.00],
    [0.75, 0.75],
], dtype=np.float64)
probe_latent = reg.decision_function(probe_points)
probe_var = reg.predictive_variance(probe_points)
probe_mean_count = reg.total_count_ * np.exp(probe_latent + 0.5 * probe_var)
probe_summary = np.column_stack([probe_points, probe_latent, probe_var, probe_mean_count])

print("Columns: x1, x2, latent_mean, latent_variance, predicted_mean_count")
np.round(probe_summary, 3)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 latent_grid = reg.decision_function(X_grid_np)
#       6 print('...')
# ----> 7 var_grid = reg.predictive_variance(X_grid_np)
#       8 print('...')
#       9 mean_count_grid = reg.total_count_ * np.exp(latent_grid + 0.5 * var_grid)
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:1489, in _BasePolyagammaGPEstimator.predictive_variance(self, X)
#    1486     return self.posterior_var_diag_.copy()
#    1488 X_t = torch.as_tensor(X_arr, device=self._device_, dtype=self._rdtype_)
# -> 1489 variance = self._predictive_variance_off_train(X_t)
#    1490 return variance.detach().cpu().numpy()
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:1200, in _BasePolyagammaGPEstimator._predictive_variance_off_train(self, X_t)
#    1187     variance, _ = _predictive_variance_stochastic(
#    1188         X_t,
#    1189         self._variational_state_.delta,
#    (...)
#    1197         weighted_toeplitz=weighted_toeplitz,
#    1198     )
#    1199 else:
# -> 1200     variance, _ = _predictive_variance_chebyshev(
#    1201         X_t,
#    1202         self._variational_state_.delta,
#    1203         self._spectral_state_,
#    1204         cg_tol=self.cg_tol,
#    1205         nufft_eps=self.nufft_eps,
#    1206         n_nodes_per_dim=self.predictive_variance_chebyshev_nodes,
#    1207         use_exact_weighted_toeplitz_operator=self.use_exact_weighted_toeplitz_operator,
#    1208         batch_size=self.prediction_batch_size,
#    1209         weighted_toeplitz=weighted_toeplitz,
#    1210     )
#    1211 return variance
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:1002, in _predictive_variance_chebyshev(X_new, delta, spectral, cg_tol, nufft_eps, n_nodes_per_dim, use_exact_weighted_toeplitz_operator, batch_size, weighted_toeplitz)
#    1000 mesh = torch.meshgrid(*node_axes_t, indexing="ij")
#    1001 node_points = torch.stack([g.reshape(-1) for g in mesh], dim=1)
# -> 1002 node_variance = _predictive_variance(
#    1003     node_points,
#    1004     delta,
#    1005     spectral,
#    1006     cg_tol=cg_tol,
#    1007     nufft_eps=nufft_eps,
#    1008     use_exact_weighted_toeplitz_operator=use_exact_weighted_toeplitz_operator,
#    1009     batch_size=batch_size,
#    1010     weighted_toeplitz=weighted_toeplitz,
#    1011 )
#    1012 node_shape = (n_nodes_per_dim,) * dimension
#    1013 interpolated = _tensor_product_barycentric_interpolate(
#    1014     node_variance.reshape(node_shape).to(dtype=delta.dtype),
#    1015     barycentric_mats,
#    1016 ).clamp_min(0.0)
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:766, in _predictive_variance(X_new, delta, spectral, cg_tol, nufft_eps, use_exact_weighted_toeplitz_operator, batch_size, weighted_toeplitz)
#     755 def _predictive_variance(
#     756     X_new: torch.Tensor,
#     757     delta: torch.Tensor,
#    (...)
#     764     weighted_toeplitz: ToeplitzND | None = None,
#     765 ) -> torch.Tensor:
# --> 766     _, variance = _predictive_latent_moments(
#     767         X_new,
#     768         None,
#     769         delta,
#     770         spectral,
#     771         cg_tol=cg_tol,
#     772         nufft_eps=nufft_eps,
#     773         use_exact_weighted_toeplitz_operator=use_exact_weighted_toeplitz_operator,
#     774         batch_size=batch_size,
#     775         weighted_toeplitz=weighted_toeplitz,
#     776     )
#     777     return variance
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:743, in _predictive_latent_moments(X_new, beta_mean, delta, spectral, cg_tol, nufft_eps, use_exact_weighted_toeplitz_operator, batch_size, weighted_toeplitz)
#     737 else:
#     738     mean_block = torch.sum(
#     739         phi_block.conj() * (ws2_row * beta_mean.unsqueeze(0)),
#     740         dim=1,
#     741     ).real
# --> 743 beta_block, _ = solve_A_beta(phi_block)
#     744 variance_block = torch.sum(
#     745     phi_block.conj() * (ws2_row * beta_block),
#     746     dim=1,
#     747 ).real.clamp_min(0.0)
#     749 means.append(mean_block)
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:512, in _make_feature_space_solver.<locals>.solve_A_beta(q)
#     502 rhs = Ds * q if q.dim() == 1 else q * Ds[None, :]
#     504 cg = ConjugateGradients(
#     505     apply_IpS,
#     506     rhs,
#    (...)
#     510     early_stopping=True,
#     511 )
# --> 512 y = cg.solve()
#     513 info["cg_iters"] = int(cg.iters_completed)
#     514 beta = Dsinv * y if q.dim() == 1 else y * Dsinv[None, :]
#
# File ~/Documents/GPs/gp-quadrature/cg.py:82, in ConjugateGradients.solve(self)
#      74 """
#      75 Solve the linear system(s) using Conjugate Gradients.
#      76 Automatically handles single or batched systems.
#    (...)
#      79     x (torch.Tensor): Solution to the system(s)
#      80 """
#      81 if self.is_batched:
# ---> 82     return self._solve_batched()
#      83 else:
#      84     return self._solve_single()
#
# File ~/Documents/GPs/gp-quadrature/cg.py:202, in ConjugateGradients._solve_batched(self)
#     199     break
#     201 # Compute matrix-vector product for active systems
# --> 202 Ap = self.A_apply_function(p[idx])  # (k, n)
#     204 # Compute step sizes
#     205 pAp = torch.sum(p[idx].conj() * Ap, dim=1).real + self.div_eps  # (k,)
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:499, in _make_feature_space_solver.<locals>.apply_IpS(Y)
#     498 def apply_IpS(Y: torch.Tensor) -> torch.Tensor:
# --> 499     return Y + apply_S(Y)
#
# File ~/Documents/GPs/gp-quadrature/polyagamma_classification/pg_classifier.py:485, in _make_feature_space_solver.<locals>.apply_S(Y)
#     483         return Ds * weighted_toeplitz_op(t)
#     484     t = Y * Ds[None, :]
# --> 485     return Ds[None, :] * weighted_toeplitz_op(t)
#     486 if Y.dim() == 1:
#     487     t = Ds * Y
#
# File ~/Documents/GPs/gp-quadrature/efgpnd.py:1430, in ToeplitzND.__call__(self, x)
#    1427 x_pad = nnf.pad(x, pad)
#    1429 # --- Perform FFT convolution ---
# -> 1430 x_fft = fftn(x_pad, dim=list(range(-self.d, 0)))
#    1432 # Multiply in frequency domain
#    1433 if self.fft_kernel is not None:
#
# KeyboardInterrupt:

# %%
extent = [grid_1d_np.min(), grid_1d_np.max(), grid_1d_np.min(), grid_1d_np.max()]

fig, axes = plt.subplots(2, 3, figsize=(14, 9), constrained_layout=True)

scatter = axes[0, 0].scatter(
    X_train_np[:, 0],
    X_train_np[:, 1],
    c=y_train_np,
    cmap="plasma",
    s=40,
    edgecolors="black",
)
axes[0, 0].set_title("Observed counts")
axes[0, 0].set_xlabel("x1")
axes[0, 0].set_ylabel("x2")
fig.colorbar(scatter, ax=axes[0, 0], fraction=0.046)

# Get common vmin/vmax for true and predicted latent
latent_vmin = min(f_grid_true_img.min(), latent_grid_img.min())
latent_vmax = max(f_grid_true_img.max(), latent_grid_img.max())

im1 = axes[0, 1].imshow(
    f_grid_true_img.T,
    origin="lower",
    extent=extent,
    cmap="viridis",
    aspect="auto",
    vmin=latent_vmin,
    vmax=latent_vmax,
)
# axes[0, 1].scatter(X_train_np[:, 0], X_train_np[:, 1], c=y_train_np, cmap="plasma", s=12, edgecolors="black")
axes[0, 1].set_title("True latent sample")
axes[0, 1].set_xlabel("x1")
axes[0, 1].set_ylabel("x2")
fig.colorbar(im1, ax=axes[0, 1], fraction=0.046)

im2 = axes[0, 2].imshow(
    latent_grid_img.T,
    origin="lower",
    extent=extent,
    cmap="viridis",
    aspect="auto",
    vmin=latent_vmin,
    vmax=latent_vmax,
)
# axes[0, 2].scatter(X_train_np[:, 0], X_train_np[:, 1], c=y_train_np, cmap="plasma", s=12, edgecolors="black")
axes[0, 2].set_title("Predicted latent mean")
axes[0, 2].set_xlabel("x1")
axes[0, 2].set_ylabel("x2")
fig.colorbar(im2, ax=axes[0, 2], fraction=0.046)

# Get common vmin/vmax for true and predicted mean count
count_vmin = min(mean_count_grid_true_img.min(), mean_count_grid_img.min())
count_vmax = max(mean_count_grid_true_img.max(), mean_count_grid_img.max())

im3 = axes[1, 0].imshow(
    mean_count_grid_true_img.T,
    origin="lower",
    extent=extent,
    cmap="magma",
    aspect="auto",
    vmin=count_vmin,
    vmax=count_vmax,
)
# axes[1, 0].scatter(X_train_np[:, 0], X_train_np[:, 1], c=y_train_np, cmap="plasma", s=12, edgecolors="black")
axes[1, 0].set_title("True mean count")
axes[1, 0].set_xlabel("x1")
axes[1, 0].set_ylabel("x2")
fig.colorbar(im3, ax=axes[1, 0], fraction=0.046)

im4 = axes[1, 1].imshow(
    mean_count_grid_img.T,
    origin="lower",
    extent=extent,
    cmap="magma",
    aspect="auto",
    vmin=count_vmin,
    vmax=count_vmax,
)
# axes[1, 1].scatter(X_train_np[:, 0], X_train_np[:, 1], c=y_train_np, cmap="plasma", s=12, edgecolors="black")
axes[1, 1].set_title("Predicted mean count")
axes[1, 1].set_xlabel("x1")
axes[1, 1].set_ylabel("x2")
fig.colorbar(im4, ax=axes[1, 1], fraction=0.046)

im5 = axes[1, 2].imshow(
    var_grid_img.T,
    origin="lower",
    extent=extent,
    cmap="cividis",
    aspect="auto",
)
# axes[1, 2].scatter(X_train_np[:, 0], X_train_np[:, 1], c=y_train_np, cmap="plasma", s=12, edgecolors="black")
axes[1, 2].set_title("Predictive latent variance")
axes[1, 2].set_xlabel("x1")
axes[1, 2].set_ylabel("x2")
fig.colorbar(im5, ax=axes[1, 2], fraction=0.046)

fig.suptitle("Polyagamma GP Negative Binomial Demo", fontsize=16)
# Out:
# Text(0.5, 0.98, 'Polyagamma GP Negative Binomial Demo')
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
history = reg.history_
iters = np.array([row["iter"] for row in history], dtype=float)
lengthscales = np.array([row["lengthscale"] for row in history], dtype=float)
variances = np.array([row["variance"] for row in history], dtype=float)
total_counts = np.array([row["total_count"] for row in history], dtype=float)
count_mae = np.array([row["mean_count_mae"] for row in history], dtype=float)
e_residuals = np.array([row["e_residual"] for row in history], dtype=float)
m_cg_iters = np.array([row["m_cg_iters"] for row in history], dtype=float)

fig, axes = plt.subplots(1, 3, figsize=(15, 4), constrained_layout=True)

axes[0].plot(iters, lengthscales, marker="o", color="#6a4c93", label="Lengthscale")
axes[0].plot(iters, variances, marker="s", color="#1982c4", label="Variance")
axes[0].set_title("Kernel trajectory")
axes[0].set_xlabel("Outer iteration")
axes[0].legend(loc="best")

axes[1].plot(iters, total_counts, marker="o", color="#ff595e", label="Learned r")
axes[1].axhline(true_total_count, color="black", linestyle="--", linewidth=1.5, label="True r")
axes[1].axhline(init_total_count, color="#8d99ae", linestyle=":", linewidth=1.5, label="Initial r")
axes[1].set_title("Shape-parameter trajectory")
axes[1].set_xlabel("Outer iteration")
axes[1].legend(loc="best")

axes[2].plot(iters, count_mae, marker="^", color="#8ac926", label="Mean-count MAE")
axes[2].plot(iters, e_residuals, marker="d", color="#ff595e", label="E-step residual")
axes[2].plot(iters, m_cg_iters, marker="x", color="#ffca3a", label="M-step CG iters")
axes[2].set_title("Training diagnostics")
axes[2].set_xlabel("Outer iteration")
axes[2].legend(loc="best")

# %%
# --- Lengthscale learning curve (presentation figure) ---
fig, ax = plt.subplots(figsize=(8, 5.5))

ax.plot(iters, lengthscales,
        '-o', color='#6a4c93', ms=6, lw=2.5,
        label=f'PG-NegBin ({fit_time:.0f}s)')

ax.axhline(true_length_scale, color='black', ls=':', lw=2,
           label=f'True ({true_length_scale})')

ax.set_xlabel('Iteration', fontsize=14)
ax.set_ylabel('Lengthscale', fontsize=14)
ax.set_title(f'Lengthscale Recovery (n={n_train:,}, d={d})', fontsize=15)
ax.tick_params(labelsize=12)
ax.legend(fontsize=10, loc='best', framealpha=0.9)
ax.grid(True, alpha=0.3)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Exact Dense Latent Log-Density Sanity Check
#
# As in the fixed-`r` notebook, the exact observed-data marginal $p(y \mid \theta, r)$ is not available in closed form. We therefore keep the same sanity check: the exact dense GP log density of the sampled training latent $f_{\mathrm{train}}$ under the analytic squared-exponential kernel, with the learned kernel path overlaid. The learned `r` trajectory is shown separately above.

# %%
def exact_latent_log_density(X, f, lengthscale, variance, jitter=1e-6):
    K = squared_exponential_kernel(X, X, length_scale=float(lengthscale), variance=float(variance))
    K = K + jitter * torch.eye(X.shape[0], dtype=X.dtype, device=X.device)
    L = torch.linalg.cholesky(K)
    alpha = torch.cholesky_solve(f.unsqueeze(-1), L).squeeze(-1)
    logdet = 2.0 * torch.sum(torch.log(torch.diagonal(L)))
    n = X.shape[0]
    return float(-0.5 * (torch.dot(f, alpha) + logdet + n * np.log(2.0 * np.pi)))

ls_min = max(0, min(lengthscales.min(), true_length_scale) * 0.5)
ls_max = max(lengthscales.max(), true_length_scale) * 1.5
var_min = max(0, min(variances.min(), true_variance) * 0.5)
var_max = max(variances.max(), true_variance) * 1.75

fig, ax = plt.subplots(figsize=(7.5, 5.5), constrained_layout=True)
ax.plot(lengthscales, variances, color="black", linewidth=2, marker="o", markersize=4, label="Training path")
ax.scatter([true_length_scale], [true_variance], color="red", marker="*", s=180, label="True hyperparams")
ax.scatter([lengthscales[-1]], [variances[-1]], color="orange", marker="s", s=70, label="Final PG iterate")
ax.set_xlabel("Lengthscale")
ax.set_ylabel("Variance")
ax.set_title("PG Training Path vs True Hyperparameters")
ax.legend(loc="best")
ax.set_xlim(ls_min, ls_max)
ax.set_ylim(var_min, var_max)

print(f"Final PG iterate: lengthscale={lengthscales[-1]:.3f}, variance={variances[-1]:.3f}")
print(f"True hyperparams: lengthscale={true_length_scale:.3f}, variance={true_variance:.3f}")
# Out:
# Final PG iterate: lengthscale=0.202, variance=1.144
# True hyperparams: lengthscale=0.200, variance=1.000
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# print("First five observed counts:", y_train_np[:5].astype(int))
# print("First five predicted mean counts:", np.round(mean_count_train[:5], 3))
# print("First five training variances:", np.round(var_train[:5], 3))
# print("First five latent predictions:", np.round(latent_train[:5], 3))
# print("First six learned r values:", np.round(total_counts[:6], 3))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
